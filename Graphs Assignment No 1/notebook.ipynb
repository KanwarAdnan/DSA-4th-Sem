# %%
from numpy import arange, log
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# Data
X = arange(1,1500)
print(f"X = {X}")
# Out:
# X = [   1    2    3 ... 1497 1498 1499]

# %%
# Plotting Function
def myPlot(title,x,y):
  plt.title(title)
  plt.xlabel("X-Axis")
  plt.ylabel("Y-Axis")
  print(f"Y = {y}")
  plt.plot(x,y)

# %%
# Function 1
Y = (2*X)
myPlot("Y = 2x",X,Y)
plt.show()
# Out:
# Y = [   2    4    6 ... 2994 2996 2998]

# %%
# Function 2
Y = (3*X)
myPlot("Y = 3x",X,Y)
plt.show()
# Out:
# Y = [   3    6    9 ... 4491 4494 4497]

# %%
# Function 3
Y = (X**3)
myPlot("Y = x^3",X,Y)
plt.show()
# Out:
# Y = [         1          8         27 ... 3354790473 3361517992 3368254499]

# %%
# Function 4
Y = log(X)
myPlot("Y = log x",X,Y)
plt.show()
# Out:
# Y = [0.         0.69314718 1.09861229 ... 7.31121838 7.31188616 7.3125535 ]

# %%
# Function 5
Y = (2*(X**2))+(3*X)
myPlot("Y=2x^2 + 3x",X,Y)
plt.show()
# Out:
# Y = [      5      14      27 ... 4486509 4492502 4498499]

# %%
# Function 6
Y = (3*X)+2
myPlot("Y = 3x + 2",X,Y)
plt.show()
# Out:
# Y = [   5    8   11 ... 4493 4496 4499]

# %%
# Function 7
Y = (X**2)
myPlot("",X,Y)
Y = 1000*X
myPlot("Y = x^2 vs Y = 1000x",X,Y)
plt.legend(['y = x^2', 'y = 1000x'])
plt.show()
# Out:
# Y = [      1       4       9 ... 2241009 2244004 2247001]
# Y = [   1000    2000    3000 ... 1497000 1498000 1499000]

# %% [markdown]
# They are intersecting at point (0,0) and at x=1000.
